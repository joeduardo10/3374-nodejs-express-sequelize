# %% [markdown]
# <a href="https://colab.research.google.com/github/joeduardo10/3374-nodejs-express-sequelize/blob/arquivos-iniciais/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip -q install google-genai

# %%
# Configura a API Key do Google Gemini

import os
from google.colab import userdata

os.environ["GOOGLE_API_KEY"] = userdata.get('GOOGLE_API_KEY')

# %%
# Configura o cliente da SDK do Gemini

from google import genai

client = genai.Client()

MODEL_ID = "gemini-2.0-flash"

# %%
# Pergunta ao Gemini uma informação mais recente que seu conhecimento

from IPython.display import HTML, Markdown

# Perguntar pro modelo quando é a próxima imersão de IA ###############################################
resposta = client.models.generate_content(
    model=MODEL_ID,
    contents='Quando é a próxima Imersão IA com Google Gemini da Alura?',
)

# %%
# Pergunta ao Gemini uma informação mais recente que seu conhecimento

from IPython.display import HTML, Markdown

# Perguntar pro modelo quando é a próxima imersão de IA ###############################################
resposta = client.models.generate_content(
    model=MODEL_ID,
    contents='Quando é a próxima Imersão IA com Google Gemini da Alura?',
)

# %%
# !pip install -q google-adk
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 21.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.1/232.1 kB 15.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 217.1/217.1 kB 14.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 334.1/334.1 kB 22.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.1/125.1 kB 9.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.0/119.0 kB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.9/194.9 kB 13.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 5.3 MB/s eta 0:00:00

# %%
from google.adk.agents import Agent
from google.adk.runners import Runner
from google.adk.sessions import InMemorySessionService
from google.adk.tools import google_search
from google.genai import types  # Para criar conteúdos (Content e Part)
from datetime import date
import textwrap # Para formatar melhor a saída de texto
from IPython.display import display, Markdown # Para exibir texto formatado no Colab
import requests # Para fazer requisições HTTP
import warnings

warnings.filterwarnings("ignore")

# %%
# Função auxiliar que envia uma mensagem para um agente via Runner e retorna a resposta final
def call_agent(agent: Agent, message_text: str) -> str:
    # Cria um serviço de sessão em memória
    session_service = InMemorySessionService()
    # Cria uma nova sessão (você pode personalizar os IDs conforme necessário)
    session = session_service.create_session(app_name=agent.name, user_id="user1", session_id="session1")
    # Cria um Runner para o agente
    runner = Runner(agent=agent, app_name=agent.name, session_service=session_service)
    # Cria o conteúdo da mensagem de entrada
    content = types.Content(role="user", parts=[types.Part(text=message_text)])

    final_response = ""
    # Itera assincronamente pelos eventos retornados durante a execução do agente
    for event in runner.run(user_id="user1", session_id="session1", new_message=content):
        if event.is_final_response():
          for part in event.content.parts:
            if part.text is not None:
              final_response += part.text
              final_response += "\n"
    return final_response

# %%
# Função auxiliar para exibir texto formatado em Markdown no Colab
def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
##########################################
# --- Agente 1: Buscador de Notícias --- #
##########################################
def agente_buscador(topico, data_de_hoje):

    buscador = Agent(
        name="agente_buscador",
        model="gemini-2.0-flash",
        instruction="""
        Você é um assistente de pesquisa. A sua tarefa é usar a ferramenta de busca do google (google_search)
        para recuperar as últimas notícias de lançamentos muito relevantes sobre o tópico abaixo.
        Foque em no máximo 5 lançamentos relevantes, com base na quantidade e entusiasmo das notícias sobre ele.
        Se um tema tiver poucas notícias ou reações entusiasmadas, é possível que ele não seja tão relevante assim
        e pode ser substituído por outro que tenha mais.
        Esses lançamentos relevantes devem ser atuais, de no máximo um mês antes da data de hoje.
        """,
        description="Agente que busca informações no Google",
        tools=[google_search]
    )

    entrada_do_agente_buscador = f"Tópico: {topico}\nData de hoje: {data_de_hoje}"

    lancamentos = call_agent(buscador, entrada_do_agente_buscador)
    return lancamentos

# %%
################################################
# --- Agente 2: Planejador de posts --- #
################################################
def agente_planejador(topico, lancamentos_buscados):
    planejador = Agent(
        name="agente_planejador",
        model="gemini-2.0-flash",
        # Inserir as instruções do Agente Planejador #################################################
        instruction="""
        Você é um planejador de conteúdo, especialista em redes sociais. Com base na lista de
        lançamentos mais recentes e relevantes buscador, você deve:
        usar a ferramenta de busca do Google (google_search) para criar um plano sobre
        quais são os pontos mais relevantes que poderíamos abordar em um post sobre
        cada um deles. Você também pode usar o (google_search) para encontrar mais
        informações sobre os temas e aprofundar.
        Ao final, você irá escolher o tema mais relevante entre eles com base nas suas pesquisas
        e retornar esse tema, seus pontos mais relevantes, e um plano com os assuntos
        a serem abordados no post que será escrito posteriormente.
        """,
        description="Agente que planeja posts",
        tools=[google_search]
    )

    entrada_do_agente_planejador = f"Tópico:{topico}\nLançamentos buscados: {lancamentos_buscados}"
    # Executa o agente
    plano_do_post = call_agent(planejador, entrada_do_agente_planejador)
    return plano_do_post

# %%
######################################
# --- Agente 3: Redator do Post --- #
######################################
def agente_redator(topico, plano_de_post):
    redator = Agent(
        name="agente_redator",
        model="gemini-2.5-pro-preview-03-25",
        instruction="""
            Você é um Redator Criativo especializado em criar posts virais para redes sociais.
            Você escreve posts para a empresa Alura, a maior escola online de tecnologia do Brasil.
            Utilize o tema fornecido no plano de post e os pontos mais relevantes fornecidos e, com base nisso,
            escreva um rascunho de post para Instagram sobre o tema indicado.
            O post deve ser engajador, informativo, com linguagem simples e incluir 2 a 4 hashtags no final.
            """,
        description="Agente redator de posts engajadores para Instagram"
    )
    entrada_do_agente_redator = f"Tópico: {topico}\nPlano de post: {plano_de_post}"
    # Executa o agente
    rascunho = call_agent(redator, entrada_do_agente_redator)
    return rascunho

# %%
##########################################
# --- Agente 4: Revisor de Qualidade --- #
##########################################
def agente_revisor(topico, rascunho_gerado):
    revisor = Agent(
        name="agente_revisor",
        model="gemini-2.5-pro-preview-03-25",
        instruction="""
            Você é um Editor e Revisor de Conteúdo meticuloso, especializado em posts para redes sociais, com foco no Instagram.
            Por ter um público jovem, entre 18 e 30 anos, use um tom de escrita adequado.
            Revise o rascunho de post de Instagram abaixo sobre o tópico indicado, verificando clareza, concisão, correção e tom.
            Se o rascunho estiver bom, responda apenas 'O rascunho está ótimo e pronto para publicar!'.
            Caso haja problemas, aponte-os e sugira melhorias.
            """,
        description="Agente revisor de post para redes sociais."
    )
    entrada_do_agente_revisor = f"Tópico: {topico}\nRascunho: {rascunho_gerado}"
    # Executa o agente
    texto_revisado = call_agent(revisor, entrada_do_agente_revisor)
    return texto_revisado

# %%
data_de_hoje = date.today().strftime("%d/%m/%Y")

print("🚀 Iniciando o Sistema de Criação de Posts para Instagram com 4 Agentes 🚀")

# --- Obter o Tópico do Usuário ---
topico = input("❓ Por favor, digite o TÓPICO sobre o qual você quer criar o post de tendências: ")

# Inserir lógica do sistema de agentes ################################################
if not topico:
    print("Você esqueceu de digitar o tópico!")
else:
    print(f"Maravilha! Vamos então criar o post sobre novidades em {topico}")

    lancamentos_buscados = agente_buscador(topico, data_de_hoje)
    print("\n--- 📝 Resultado do Agente 1 (Buscador) ---\n")
    display(to_markdown(lancamentos_buscados))
    print("--------------------------------------------------------------")

    plano_de_post = agente_planejador(topico, lancamentos_buscados)
    print("\n--- 📝 Resultado do Agente 2 (Planejador) ---\n")
    display(to_markdown(plano_de_post))
    print("--------------------------------------------------------------")

    rascunho_de_post = agente_redator(topico, plano_de_post)
    print("\n--- 📝 Resultado do Agente 3 (Redator) ---\n")
    display(to_markdown(rascunho_de_post))
    print("--------------------------------------------------------------")

    post_final = agente_revisor(topico, rascunho_de_post)
    print("\n--- 📝 Resultado do Agente 4 (Revisor) ---\n")
    display(to_markdown(post_final))
    print("--------------------------------------------------------------")
# Out:
# 🚀 Iniciando o Sistema de Criação de Posts para Instagram com 4 Agentes 🚀
# ❓ Por favor, digite o TÓPICO sobre o qual você quer criar o post de tendências: agentes de IA
# Maravilha! Vamos então criar o post sobre novidades em agentes de IA
#
# --- 📝 Resultado do Agente 1 (Buscador) ---
# > Tudo bem, vou buscar no Google os lançamentos mais recentes e relevantes sobre agentes de IA, focando nos últimos 30 dias e priorizando aqueles com mais notícias e entusiasmo.
# >
# >
# > Com certeza! Aqui estão alguns dos lançamentos e temas mais relevantes sobre agentes de IA nas últimas semanas, com base nas notícias encontradas:
# >
# > 1.  **Agentes de IA Transformando o Comércio:** Um relatório da Visa e do Institute for the Future (IFTF) indica que os agentes de IA vão alterar drasticamente a forma como compramos. O relatório aponta que 82% dos brasileiros demonstram interesse em assistentes pessoais com IA. A expectativa é que a IA revolucione a forma como os indivíduos lidam com finanças.
# > 2.  **Atualizações e Lançamentos de Grandes Empresas:** Empresas como IBM, Anthropic, Amazon, Google e OpenAI anunciaram atualizações e lançamentos que prometem revolucionar o cenário da IA. A IBM, por exemplo, anunciou novas ferramentas integradas ao watsonx Orchestrate para integrar, customizar e implantar agentes, além de disponibilizar agentes pré-construídos para áreas como RH, vendas e compras. A OpenAI adquiriu a Windsurf, um ambiente de desenvolvimento colaborativo que permite a integração entre desenvolvedores e agentes inteligentes.
# > 3.  **IAedu: Plataforma para Democratizar o Acesso à IA no Ensino Superior:** A Fundação para a Ciência e a Tecnologia (FCT) lançou o IAedu, um serviço digital que visa democratizar o acesso a tecnologias de IA no ensino superior e na investigação científica em Portugal. A plataforma oferecerá acesso centralizado e gratuito a modelos de linguagem de larga escala (LLM). A segunda edição da plataforma incluirá uma funcionalidade de criação de agentes virtuais personalizados.
# > 4.  **Mind of Pepe (MIND):** É um projeto de memecoin com um agente de IA autônomo e autoevolutivo que oferece insights sobre o mercado de criptomoedas. Ele pode interagir em plataformas sociais para discutir e gerar ideias, e os detentores do token podem obter insights exclusivos e recompensas por staking.
# > 5.  **Tokens de Agentes de IA:** Tokens de agentes de IA estão ganhando força no mercado de criptomoedas, alimentando ferramentas e aplicativos de IA descentralizados. Alguns exemplos incluem AIXBT (bot de IA de cadeia cruzada), CGPT (Crypto GPT) e COOKIE (assistentes virtuais personalizados para plataformas de jogos e negociação NFT).
# >
# > Espero que esta pesquisa seja útil!
# --------------------------------------------------------------
#
# --- 📝 Resultado do Agente 2 (Planejador) ---
# > Com certeza! Para criar um plano de conteúdo eficaz sobre agentes de IA, vamos analisar cada um dos temas que você encontrou e identificar os pontos mais relevantes para o público.
# >
# > **1. Agentes de IA Transformando o Comércio:**
# >
# > *   **Pontos Relevantes:**
# >     *   Impacto na experiência de compra do consumidor.
# >     *   Adoção crescente de assistentes pessoais com IA no Brasil (82% de interesse).
# >     *   Revolução na gestão de finanças pessoais.
# >     *   Oportunidades para empresas personalizarem ofertas e serviços.
# > *   **Plano de Conteúdo:**
# >     *   **Título:** "Como os Agentes de IA Vão Mudar a Forma Como Você Compra (e Economiza Dinheiro)"
# >     *   **Assuntos a Abordar:**
# >         *   O que são agentes de IA e como eles funcionam no comércio.
# >         *   Exemplos práticos de como os agentes de IA já estão sendo usados (e como serão usados no futuro).
# >         *   Benefícios para os consumidores: personalização, conveniência, economia.
# >         *   Benefícios para as empresas: otimização de vendas, melhor atendimento, insights de dados.
# >         *   Dados do relatório da Visa/IFTF sobre o interesse dos brasileiros.
# >         *   Dicas de como se preparar para essa transformação e aproveitar ao máximo os agentes de IA.
# >     *   **Formato:** Artigo de blog, vídeo curto, infográfico.
# >
# > **2. Atualizações e Lançamentos de Grandes Empresas:**
# >
# > *   **Pontos Relevantes:**
# >     *   Inovações e novas ferramentas para desenvolvedores e empresas.
# >     *   Integração, customização e implantação simplificadas de agentes.
# >     *   Agentes pré-construídos para diversas áreas (RH, vendas, etc.).
# >     *   Aquisição da Windsurf pela OpenAI e o impacto na colaboração.
# > *   **Plano de Conteúdo:**
# >     *   **Título:** "As Big Techs Estão Acelerando a Era dos Agentes de IA: Veja as Novidades da IBM, OpenAI e Mais"
# >     *   **Assuntos a Abordar:**
# >         *   Visão geral das principais atualizações e lançamentos (IBM watsonx, OpenAI/Windsurf, etc.).
# >         *   Detalhes sobre as novas funcionalidades e como elas facilitam o desenvolvimento de agentes.
# >         *   Exemplos de casos de uso para os agentes pré-construídos.
# >         *   Análise do impacto da aquisição da Windsurf na colaboração entre desenvolvedores.
# >         *   Perspectivas sobre o futuro dos agentes de IA com base nessas inovações.
# >     *   **Formato:** Artigo técnico, vídeo de demonstração, podcast.
# >
# > **3. IAedu: Plataforma para Democratizar o Acesso à IA no Ensino Superior:**
# >
# > *   **Pontos Relevantes:**
# >     *   Acesso gratuito a LLMs para estudantes e pesquisadores em Portugal.
# >     *   Criação de agentes virtuais personalizados para fins educacionais.
# >     *   Potencial para transformar o ensino e a pesquisa em IA.
# > *   **Plano de Conteúdo:**
# >     *   **Título:** "IA para Todos: Plataforma IAedu Democratiza o Acesso à Inteligência Artificial no Ensino Superior"
# >     *   **Assuntos a Abordar:**
# >         *   O que é a IAedu e como ela funciona.
# >         *   Benefícios do acesso gratuito a LLMs para estudantes e pesquisadores.
# >         *   Exemplos de como os agentes virtuais personalizados podem ser usados em sala de aula e na pesquisa.
# >         *   Impacto da plataforma na formação de profissionais de IA e no avanço da ciência.
# >         *   Entrevistas com usuários da IAedu (se possível).
# >     *   **Formato:** Artigo de notícias, estudo de caso, vídeo explicativo.
# >
# > **4. Mind of Pepe (MIND):**
# >
# > *   **Pontos Relevantes:**
# >     *   Agente de IA autônomo para insights sobre o mercado de criptomoedas.
# >     *   Interação em plataformas sociais para discutir e gerar ideias.
# >     *   Recompensas para detentores do token.
# > *   **Plano de Conteúdo:**
# >     *   **Título:** "Mind of Pepe: Memecoin com Agente de IA que Dá Insights Sobre Criptomoedas"
# >     *   **Assuntos a Abordar:**
# >         *   O que é Mind of Pepe e como ele se diferencia de outras memecoins.
# >         *   Como o agente de IA autônomo gera insights sobre o mercado.
# >         *   Exemplos de interações do agente em plataformas sociais.
# >         *   Benefícios para os detentores do token (recompensas, insights exclusivos).
# >         *   Riscos e oportunidades de investir em memecoins com IA.
# >     *   **Formato:** Artigo de análise, vídeo de entrevista, thread no Twitter.
# >
# > **5. Tokens de Agentes de IA:**
# >
# > *   **Pontos Relevantes:**
# >     *   Crescimento do mercado de tokens de agentes de IA.
# >     *   Exemplos de projetos (AIXBT, CGPT, COOKIE) e suas aplicações.
# >     *   Potencial para descentralizar ferramentas e aplicativos de IA.
# > *   **Plano de Conteúdo:**
# >     *   **Título:** "Tokens de Agentes de IA: A Nova Fronteira das Criptomoedas e da Inteligência Artificial Descentralizada"
# >     *   **Assuntos a Abordar:**
# >         *   O que são tokens de agentes de IA e como eles funcionam.
# >         *   Exemplos de projetos promissores (AIXBT, CGPT, COOKIE) e suas aplicações.
# >         *   Vantagens da descentralização de ferramentas de IA.
# >         *   Riscos e oportunidades de investir em tokens de agentes de IA.
# >         *   Perspectivas sobre o futuro desse mercado.
# >     *   **Formato:** Artigo de análise, lista de projetos, vídeo explicativo.
# >
# > **Escolha do Tema Mais Relevante:**
# >
# > Com base nas pesquisas e no potencial de engajamento do público, o tema mais relevante para um post seria:
# >
# > **"Agentes de IA Transformando o Comércio"**
# >
# > *   **Justificativa:** Este tema tem um apelo amplo, pois afeta diretamente a vida dos consumidores e das empresas. O interesse dos brasileiros por assistentes pessoais com IA é um dado forte que pode gerar curiosidade e engajamento. Além disso, o tema oferece oportunidades para explorar exemplos práticos, dicas e previsões sobre o futuro do comércio.
# >
# > **Plano Detalhado para o Post Escolhido:**
# >
# > *   **Título:** "Como os Agentes de IA Vão Mudar a Forma Como Você Compra (e Economiza Dinheiro)"
# > *   **Introdução:**
# >     *   Uma breve explicação sobre o que são agentes de IA e como eles estão se tornando cada vez mais presentes em nossas vidas.
# >     *   Uma chamada para a ação: "Prepare-se para uma revolução na forma como você compra e gerencia suas finanças!"
# > *   **Desenvolvimento:**
# >     *   **O que são agentes de IA no comércio?**
# >         *   Explicação simples e acessível.
# >         *   Exemplos de como eles funcionam: recomendação de produtos, comparação de preços, atendimento ao cliente.
# >     *   **Adoção no Brasil:**
# >         *   Destaque para o dado do relatório Visa/IFTF: 82% dos brasileiros interessados em assistentes pessoais com IA.
# >         *   O que isso significa para o futuro do comércio no país?
# >     *   **Benefícios para os consumidores:**
# >         *   Personalização: ofertas e produtos sob medida para cada cliente.
# >         *   Conveniência: compras mais rápidas e fáceis.
# >         *   Economia: comparação de preços, descontos exclusivos, gestão de orçamento.
# >     *   **Benefícios para as empresas:**
# >         *   Otimização de vendas: recomendação de produtos, upselling, cross-selling.
# >         *   Melhor atendimento: chatbots, suporte personalizado.
# >         *   Insights de dados: análise do comportamento do consumidor, identificação de tendências.
# >     *   **Exemplos práticos:**
# >         *   Casos de uso de agentes de IA em diferentes setores do comércio: varejo, e-commerce, serviços financeiros.
# >         *   Empresas que já estão usando agentes de IA com sucesso.
# >     *   **O futuro dos agentes de IA no comércio:**
# >         *   Previsões sobre como eles vão evoluir e impactar ainda mais nossas vidas.
# >         *   A importância de se preparar para essa transformação.
# > *   **Conclusão:**
# >     *   Um resumo dos principais pontos abordados no post.
# >     *   Uma chamada para a ação: "Comece a explorar o mundo dos agentes de IA e descubra como eles podem facilitar sua vida e economizar seu dinheiro!"
# > *   **Formato:** Artigo de blog com imagens, vídeos e infográficos.
# >
# > Para aprofundar ainda mais, posso realizar buscas específicas sobre como diferentes empresas estão utilizando agentes de IA no comércio, quais são as ferramentas e plataformas mais populares para desenvolver esses agentes, e quais são as tendências futuras nesse campo.
# >
# > Com base nas buscas adicionais, aqui estão algumas informações para aprofundar o plano de conteúdo:
# >
# > **Exemplos de Uso de Agentes de IA no Varejo:**
# >
# > *   **Atendimento ao Cliente:** Agentes de IA podem responder a perguntas frequentes, acompanhar pedidos, facilitar devoluções e oferecer suporte 24/7. Eles também podem analisar o comportamento do cliente para prever tendências de compra e personalizar campanhas de marketing.
# > *   **Gestão de Estoque:** Agentes de IA podem prever quando é hora de reabastecer as prateleiras, otimizar o fluxo de mercadorias e evitar excessos ou faltas de produtos.
# > *   **Recomendação de Produtos:** Agentes de IA podem sugerir produtos personalizados com base no histórico de compras do cliente, aumentando as chances de conversão.
# > *   **Otimização de Preços:** Agentes de IA podem ajustar os preços em tempo real com base na demanda e na concorrência.
# > *   **Análise de Dados:** Agentes de IA podem analisar grandes volumes de dados para identificar padrões, tendências e oportunidades que poderiam passar despercebidos por equipes humanas.
# >
# > **Ferramentas e Plataformas para Desenvolver Agentes de IA:**
# >
# > *   **Plataformas No-Code:** Chatsimple, Vertex AI, Copilot Studio.
# > *   **Frameworks Open Source:** AutoGen (Microsoft), Langchain, LangGraph.
# > *   **APIs:** OpenAI API (GPT-4), Hugging Face (Transformers).
# > *   **Ferramentas de Automação:** Rasa, Botpress, Dialogflow.
# >
# > **Tendências Futuras de Agentes de IA no Comércio:**
# >
# > *   **Personalização:** Agentes de IA serão capazes de antecipar as necessidades dos clientes e oferecer experiências cada vez mais personalizadas.
# > *   **Autonomia:** Agentes de IA serão mais autônomos e capazes de tomar decisões e executar tarefas complexas sem supervisão humana.
# > *   **Integração Multimodal:** Agentes de IA combinarão texto, imagens, vídeos e áudio para entender o mundo como nós.
# > *   **Segurança:** A IA será usada para fortalecer a segurança de dados e identificar ameaças.
# >
# > Com essas informações adicionais, você pode criar um post ainda mais completo e informativo sobre como os agentes de IA estão transformando o comércio e como os consumidores e as empresas podem se preparar para essa revolução.
# >
# Exception in thread Thread-12 (_asyncio_thread_main):
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/google/adk/runners.py", line 138, in _asyncio_thread_main
#     asyncio.run(_invoke_run_async())
#   File "/usr/lib/python3.11/asyncio/runners.py", line 190, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 654, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/google/adk/runners.py", line 126, in _invoke_run_async
#     async for event in self.run_async(
#   File "/usr/local/lib/python3.11/dist-packages/google/adk/runners.py", line 197, in run_async
#     async for event in invocation_context.agent.run_async(invocation_context):
#   File "/usr/local/lib/python3.11/dist-packages/google/adk/agents/base_agent.py", line 133, in run_async
#     async for event in self._run_async_impl(ctx):
#   File "/usr/local/lib/python3.11/dist-packages/google/adk/agents/llm_agent.py", line 246, in _run_async_impl
#     async for event in self._llm_flow.run_async(ctx):
#   File "/usr/local/lib/python3.11/dist-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 243, in run_async
#     async for event in self._run_one_step_async(invocation_context):
#   File "/usr/local/lib/python3.11/dist-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 268, in _run_one_step_async
#     async for llm_response in self._call_llm_async(
#   File "/usr/local/lib/python3.11/dist-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 483, in _call_llm_async
#     async for llm_response in llm.generate_content_async(
#   File "/usr/local/lib/python3.11/dist-packages/google/adk/models/google_llm.py", line 140, in generate_content_async
#     response = await self.api_client.aio.models.generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/google/genai/models.py", line 6672, in generate_content
#     response = await self._generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/google/genai/models.py", line 5674, in _generate_content
#     response_dict = await self._api_client.async_request(
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/google/genai/_api_client.py", line 789, in async_request
#     result = await self._async_request(http_request=http_request, stream=False)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/google/genai/_api_client.py", line 733, in _async_request
#     await errors.APIError.raise_for_async_response(response)
#   File "/usr/local/lib/python3.11/dist-packages/google/genai/errors.py", line 129, in raise_for_async_response
#     raise ClientError(status_code, response_json, response)
# google.genai.errors.ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': "Gemini 2.5 Pro Preview doesn't have a free quota tier. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.", 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_input_token_count', 'quotaId': 'GenerateContentInputTokensPerModelPerDay-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-pro-exp', 'location': 'global'}}, {'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_input_token_count', 'quotaId': 'GenerateContentInputTokensPerModelPerMinute-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-pro-exp'}}, {'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-pro-exp'}}, {'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-pro-exp'}}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '5s'}]}}
# --------------------------------------------------------------
#
# --- 📝 Resultado do Agente 3 (Redator) ---
# --------------------------------------------------------------
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-22' coro=<AsyncClient.aclose() done, defined at /usr/local/lib/python3.11/dist-packages/httpx/_client.py:1978> exception=RuntimeError('Event loop is closed')>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/httpx/_client.py", line 1985, in aclose
#     await self._transport.aclose()
#   File "/usr/local/lib/python3.11/dist-packages/httpx/_transports/default.py", line 406, in aclose
#     await self._pool.aclose()
#   File "/usr/local/lib/python3.11/dist-packages/httpcore/_async/connection_pool.py", line 353, in aclose
#     await self._close_connections(closing_connections)
#   File "/usr/local/lib/python3.11/dist-packages/httpcore/_async/connection_pool.py", line 345, in _close_connections
#     await connection.aclose()
#   File "/usr/local/lib/python3.11/dist-packages/httpcore/_async/connection.py", line 173, in aclose
#     await self._connection.aclose()
#   File "/usr/local/lib/python3.11/dist-packages/httpcore/_async/http11.py", line 258, in aclose
#     await self._network_stream.aclose()
#   File "/usr/local/lib/python3.11/dist-packages/httpcore/_backends/anyio.py", line 53, in aclose
#     await self._stream.aclose()
#   File "/usr/local/lib/python3.11/dist-packages/anyio/streams/tls.py", line 216, in aclose
#     await self.transport_stream.aclose()
#   File "/usr/local/lib/python3.11/dist-packages/anyio/_backends/_asyncio.py", line 1314, in aclose
#     self._transport.close()
#   File "/usr/lib/python3.11/asyncio/selector_events.py", line 864, in close
#     self._loop.call_soon(self._call_connection_lost, None)
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 762, in call_soon
#     self._check_closed()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 520, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Exception in thread Thread-14 (_asyncio_thread_main):
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/google/adk/runners.py", line 138, in _asyncio_thread_main
#     asyncio.run(_invoke_run_async())
#   File "/usr/lib/python3.11/asyncio/runners.py", line 190, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 654, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/google/adk/runners.py", line 126, in _invoke_run_async
#     async for event in self.run_async(
#   File "/usr/local/lib/python3.11/dist-packages/google/adk/runners.py", line 197, in run_async
#     async for event in invocation_context.agent.run_async(invocation_context):
#   File "/usr/local/lib/python3.11/dist-packages/google/adk/agents/base_agent.py", line 133, in run_async
#     async for event in self._run_async_impl(ctx):
#   File "/usr/local/lib/python3.11/dist-packages/google/adk/agents/llm_agent.py", line 246, in _run_async_impl
#     async for event in self._llm_flow.run_async(ctx):
#   File "/usr/local/lib/python3.11/dist-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 243, in run_async
#     async for event in self._run_one_step_async(invocation_context):
#   File "/usr/local/lib/python3.11/dist-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 268, in _run_one_step_async
#     async for llm_response in self._call_llm_async(
#   File "/usr/local/lib/python3.11/dist-packages/google/adk/flows/llm_flows/base_llm_flow.py", line 483, in _call_llm_async
#     async for llm_response in llm.generate_content_async(
#   File "/usr/local/lib/python3.11/dist-packages/google/adk/models/google_llm.py", line 140, in generate_content_async
#     response = await self.api_client.aio.models.generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/google/genai/models.py", line 6672, in generate_content
#     response = await self._generate_content(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/google/genai/models.py", line 5674, in _generate_content
#     response_dict = await self._api_client.async_request(
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/google/genai/_api_client.py", line 789, in async_request
#     result = await self._async_request(http_request=http_request, stream=False)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/google/genai/_api_client.py", line 733, in _async_request
#     await errors.APIError.raise_for_async_response(response)
#   File "/usr/local/lib/python3.11/dist-packages/google/genai/errors.py", line 129, in raise_for_async_response
#     raise ClientError(status_code, response_json, response)
# google.genai.errors.ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': "Gemini 2.5 Pro Preview doesn't have a free quota tier. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.", 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-pro-exp', 'location': 'global'}}, {'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-pro-exp', 'location': 'global'}}, {'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_input_token_count', 'quotaId': 'GenerateContentInputTokensPerModelPerMinute-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-pro-exp'}}, {'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_input_token_count', 'quotaId': 'GenerateContentInputTokensPerModelPerDay-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-pro-exp'}}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '4s'}]}}
# --- 📝 Resultado do Agente 4 (Revisor) ---
# --------------------------------------------------------------
